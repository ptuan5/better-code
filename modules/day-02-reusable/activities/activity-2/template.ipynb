# %% [markdown]
# # Gene Correlation Analysis
#
# This notebook identifies and plot the expression of genes highly correlated with a target gene across all tissues.

# %% [markdown]
# ### Import the reusable functions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# TODO: Import the helper functions from activity 1 and others (if necessary)
# You can use either import, or copy-paste the function in a separate code cell.

# %% [markdown]
# ### Set parameters for the analysis
#
# The number of parameters depend on how many arguments you put in your helper functions.
#
# You can choose to type it in differently each time, or have a separate yaml file.

# %%
data_dir = "../activity-1/mock_data_3_tissues"
tissue_files = {
    "Adipose": "Adipose.csv",
    "Liver": "Liver.csv",
    "Muscle": "Muscle.csv",
}

# TODO:
# Add the necessary parameters for the analysis
# Make sure the parameters are known when the report is compiled

# %% [markdown]
# ### Run the actual analysis
#
# The repeated code logic for every iteration. You should be able to copy-paste them from the solution to activity 1.

# %% [markdown]
# Identify the correlated genes

# %%
# TODO: Implement the analysis that should be repeated across all iterations

# %% [markdown]
# Plot their expression in three tissues

# %%
# TODO: Visualize the expression for selected genes for each tissue.
