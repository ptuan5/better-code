# %% [markdown]
# # Reusable Analysis Notebook Template
#
# Use this notebook template to wrap your refactored analysis in a small, parameterized workflow.

# %% [markdown]
# ## Choose The Values That Vary
#
# Fill in the values you want to make easy to change between runs.

# %%
data_path = "TODO"
alpha = 0.05

# %% [markdown]
# ## Import Your Refactored Function
#
# Replace the path below with the file that contains your cleaned function from Activity 1.

# %%
from importlib import util
from pathlib import Path

module_path = Path("TODO")
spec = util.spec_from_file_location("activity1_refactor", module_path)
activity1_refactor = util.module_from_spec(spec)
spec.loader.exec_module(activity1_refactor)

# %% [markdown]
# ## Wrap The Reusable Step
#
# Keep this wrapper smaller than the analysis function it calls.

# %%
import pandas as pd


def run_de_analysis(data_path, alpha=0.05):
    expression_matrix = pd.read_csv(data_path, index_col=0)

    # TODO:
    # Call your imported function here.
    # Return the result.

# %% [markdown]
# ## Run The Workflow

# %%
res = run_de_analysis(data_path, alpha=alpha)

print(f"Alpha: {alpha}")
print(f"Number of significant genes: {len(res)}")
print(res.head())

# %% [markdown]
# ## Reflection
#
# Add 1-2 short notes:
#
# - Which parameter improved reuse the most?
# - Which value did you decide to keep fixed?
